# %%
#10th APRIL - FSDS, GRNAI, AGENTICAI

# %%
9
# Out:
# 9

# %%
9 + 9
# Out:
# 18

# %%
9 + 9 - (10 - 3) + 3
# Out:
# 14

# %%
9 + 9 - 10 - 3 + 3
# Out:
# 8

# %% [markdown]
# numbers are called as operand + - * are called operator
# arithmatic operator
# # 1- ARITHMATIC OPERATOR (+,-,*,/,%,%%,**)
# # 2- ASSIGNMENT OPERATOR(=)
# # 3- RELATIONAL OPERATOR
# # 4-LOGICAL OPERATOR
# # 5-UNARY OPERATOR

# %%
10 + 5
# Out:
# 15

# %%
10 - 5
# Out:
# 5

# %%
10 * 5
# Out:
# 50

# %%
10 * 2
# Out:
# 20

# %%
10 ** 2 #POWER
# Out:
# 100

# %%
10 / 5 #FLOAT DIVISION
# Out:
# 2.0

# %%
10 // 5 # INT DIVISION
# Out:
# 2

# %%
10 % 5
# Out:
# 0

# %%
15 % 6
# Out:
# 3

# %%
15 // 6
# Out:
# 2

# %%
#ASSIGNMENT OPERATOR

# %%
 x = 10 
 x # x is called variable or object or identifier
# Out:
# 10

# %%
x + 2
# Out:
# 12

# %%
x += 2
x
# Out:
# 12

# %%
x += 2
x
# Out:
# 16

# %%
x += 2
x
# Out:
# 4

# %%
x -= 2
x
# Out:
# 2

# %%
x -= 2
x
# Out:
# -2

# %%
x *= 2
x
# Out:
# -8

# %%
x /= 2
x
# Out:
# -4.0

# %%
#unary opertor

# %%
n = 7
n
# Out:
# 7

# %%
m = -n
m
# Out:
# -7

# %%
1krishna = 9 # variable doesnot start with digit
# Out:
#   Cell In[32], line 1
#     1krishna = 9 # variable doesnot start with digit
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1 = 10
nit1
# Out:
# 10

# %%
krishna@ = 9 # variable should not allows specail character
# Out:
#   Cell In[34], line 1
#     krishna@ = 9 # variable should not allows specail character
#              ^
# SyntaxError: invalid syntax

# %%
nit_ =  9
nit_ # variable use only
# Out:
# 9

# %%
def = 89
def # keyword not use
# Out:
#   Cell In[36], line 1
#     def = 89
#         ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
import sys
sys.version
# Out:
# '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]'

# %%
 a = 10
 a
# Out:
# 10

# %%
a = 20
a
# Out:
# 20

# %%
type(a)
# Out:
# int

# %% [markdown]
# # PYTHON DATATYPES-->
#  - INTEGER DATATYPES
#  - FLOAT FATATYPES
#  - BOOL DATATYPES
#  - STRING DATATYPES
#  - COMPLEX DATATYPES

# %%
i = 33
print(i)
print(type(i))
# Out:
# 33
# <class 'int'>

# %%
i1, i2 = 10, 20

print(i1)
print(i2)

print(i1 + i2)
print(i1 - i2)
print(i1 * i2)
print(i1 / i2)
# Out:
# 10
# 20
# 30
# -10
# 200
# 0.5

# %% [markdown]
# #FLOAT

# %%
 cng = 120.44
 cng
# Out:
# 120.44

# %%
type(cng)
# Out:
# float

# %% [markdown]
# # STRING ('''NON TECHINCAL - TEXT, BUT TECHNICAL  WE CALLED THIS AS STRING''')

# %%
s = krishnait
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 s = krishnait
#       2 s
#
# NameError: name 'krishnait' is not defined

# %%
s = ' krishnait'
s
# Out:
# ' krishnait'

# %%
type(s)
# Out:
# str

# %%
s2 = ''' krishna  is a student of data science
         data science, ai student -- 6 month i will change my brain'''
s2
# Out:
# ' krishna  is a student of data science\n         data science, ai student -- 6 month i will change my brain'

# %%
s
# Out:
# ' krishnait'

# %%
s [:]
# Out:
# ' krishnait'

# %%
s[2:5]
# Out:
# 'ris'

# %%
True
# Out:
# True

# %%
false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 false
#
# NameError: name 'false' is not defined

# %%
False
# Out:
# False

# %%
b = True
b1 = False

# %%
b
# Out:
# True

# %%
b1
# Out:
# False

# %%
b + b1
# Out:
# 1

# %%
print(b-b1)
print(b*b1)
print(b/b1) # float division
print(b//b1) # int division
# Out:
# 1
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[63], line 3
#       1 print(b-b1)
#       2 print(b*b1)
# ----> 3 print(b/b1) # float division
#       4 print(b//b1)
#
# ZeroDivisionError: division by zero

# %%
type(bool)
# Out:
# type

# %%
type(b1)
# Out:
# bool

# %% [markdown]
# COMPLEXN -- DATATYPE WE CAN  USE MORE MATH OPERATION -- NASA, ISRO, ROBO
#
# a = bj
#
# # a - real part
# # b - imaginary part
# # j - square root of -1

# %%
c1 = 10 + 20j
c1
# Out:
# (10+20j)

# %%
type(c1)
# Out:
# complex

# %%
c1
# Out:
# (10+20j)

# %%
c1.real
# Out:
# 10.0

# %%
c1.imag
# Out:
# 20.0

# %%
c2 = 3 + 5j
c2
# Out:
# (3+5j)

# %%
print(c1)
print(c2)
# Out:
# (10+20j)
# (3+5j)

# %%
c1 + c2
# Out:
# (13+25j)

# %% [markdown]
# #PYTHON DATA TYPES

# %%
#TYPE CASTING OR TYPE CONVERSION

# %%
int(3.4) # float ti int
# Out:
# 3

# %%
int(True) # bool to int
# Out:
# 1

# %%
int(3.4, 5.7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 int(3.4, 5.7)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True, False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 int(True, False)
#
# TypeError: int() can't convert non-string with explicit base

# %%
int(False)
# Out:
# 0

# %%
print(int(3.4))
print(int(True))
print(int('10'))
# Out:
# 3
# 1
# 10

# %%
print(int(10+20j))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 print(int(10+20j))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
#FROM ALL OTHER DATATYPES TO INT TYPECASTING COMPLETED

# %%
#COMPLEX & STRING WITH TEXT IS NOT ALLOWED

# %%
print(True*2)
# Out:
# 2

# %%
poll_data = 7,
type(poll_data)
# Out:
# tuple

# %%
dict(range(9))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 dict(range(9))
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
set(range(9))
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 8}

# %%
list(range(9))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
tuple(range(9))
# Out:
# (0, 1, 2, 3, 4, 5, 6, 7, 8)

# %%
obj_data = ()
type(obj_data)
# Out:
# tuple
