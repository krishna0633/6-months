# %%
s = {}
type(s)
# Out:
# dict

# %%
s = set()
s
# Out:
# set()

# %%
type(s)
# Out:
# set

# %%
s1 = { 90,80,4,13,47,100,1}
s1
# Out:
# {1, 4, 13, 47, 80, 90, 100}

# %%
s2 = {4, 'nit', 2.3, True, 1+2j}
s2
# Out:
# {(1+2j), 2.3, 4, True, 'nit'}

# %%
s1
# Out:
# {1, 4, 13, 47, 80, 90, 100}

# %%
s1.add(200)
s1
# Out:
# {1, 4, 13, 47, 80, 90, 100, 200}

# %%
s1.add(100)
s1  #duplicate is not allowed
# Out:
# {1, 4, 13, 47, 80, 90, 100, 200}

# %%
s3 = s1.copy()
s3
# Out:
# {1, 4, 13, 47, 80, 90, 100, 200}

# %%
s1 == s3
# Out:
# True

# %%
len(s3)
# Out:
# 8

# %%
s3.clear()
s3
# Out:
# set()

# %%
len(s3)
# Out:
# 0

# %%
s1[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s1[:]
#
# TypeError: 'set' object is not subscriptable

# %%
s1[0] # not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 s1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s1.pop()
# Out:
# 80

# %%
s1
# Out:
# {1, 4, 13, 47, 90, 100, 200}

# %%
s1.pop()
s1
# Out:
# {4, 13, 47, 90, 100, 200}

# %%
s1
# Out:
# {4, 13, 47, 90, 100, 200}

# %%
s1.pop(1) # index is not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 s1.pop(1)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s1
# Out:
# {4, 13, 47, 90, 100, 200}

# %%
s1.remove(1000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 s1.remove(1000)
#
# KeyError: 1000

# %%
s1.discard(1000)

# %%
s1.remove(47)
s1
# Out:
# {4, 13, 90, 100, 200}

# %%
s1.discard
s1
# Out:
# {4, 13, 90, 100, 200}

# %%
for i in (s1):
    print(i)
# Out:
# 100
# 4
# 200
# 90
# 13

# %%
s1
# Out:
# {4, 13, 90, 100, 200}

# %%
s1.update([1,2])
s1
# Out:
# {1, 2, 4, 13, 90, 100, 200}
