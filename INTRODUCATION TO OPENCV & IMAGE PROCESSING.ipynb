# %%
#pip install opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\telan\OneDrive\Desktop\spiderman.jpeg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (312, 258, 3)

# %%
plt.imshow(img, cmap = 'gray')
plt.show()

# %%
img
# Out:
# array([[[147, 138, 128],
#         [146, 137, 127],
#         [129, 120, 110],
#         ...,
#         [188, 179, 170],
#         [189, 182, 173],
#         [189, 182, 173]],
#
#        [[145, 136, 126],
#         [150, 141, 131],
#         [139, 130, 120],
#         ...,
#         [188, 179, 170],
#         [190, 183, 174],
#         [190, 183, 174]],
#
#        [[145, 136, 126],
#         [154, 145, 135],
#         [152, 143, 133],
#         ...,
#         [190, 181, 172],
#         [191, 184, 175],
#         [191, 184, 175]],
#
#        ...,
#
#        [[  9,   2,   0],
#         [ 16,   9,   6],
#         [ 22,  15,  12],
#         ...,
#         [  2,   2,   2],
#         [  1,   1,   1],
#         [  1,   1,   1]],
#
#        [[ 11,   4,   1],
#         [ 17,  10,   7],
#         [ 22,  15,  12],
#         ...,
#         [  3,   3,   3],
#         [  1,   1,   1],
#         [  1,   1,   1]],
#
#        [[ 15,   8,   5],
#         [ 18,  11,   8],
#         [ 20,  13,  10],
#         ...,
#         [  0,   0,   0],
#         [  1,   1,   1],
#         [  1,   1,   1]]], dtype=uint8)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)
plt.show()

# %%
img_gray=cv2.imread(r"C:\Users\telan\OneDrive\Desktop\spiderman.jpeg",cv2.IMREAD_GRAYSCALE)
img_gray.shape
# Out:
# (312, 258)

# %%
img_gray.shape
# Out:
# (312, 258)

# %%
img_gray
# Out:
# array([[136, 135, 118, ..., 177, 180, 180],
#        [134, 139, 128, ..., 177, 181, 181],
#        [134, 143, 141, ..., 179, 182, 182],
#        ...,
#        [  2,   9,  15, ...,   2,   1,   1],
#        [  4,  10,  15, ...,   3,   1,   1],
#        [  8,  11,  13, ...,   0,   1,   1]], dtype=uint8)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray)
plt.show()

# %%
plt.imshow(img_gray, cmap = 'gray')
plt.show()

# %%
plt.imshow(img_gray, cmap = 'magma')
plt.show()

# %%
plt.imshow(img_gray, cmap = 'Accent')
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(fix_img)
plt.show()

# %%
fix_img.shape
# Out:
# (312, 258, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(500,367))

# %%
fix_img_1.shape
# Out:
# (367, 500, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2
# Out:
# array([[[128, 138, 147],
#         [112, 122, 131],
#         [131, 141, 150],
#         ...,
#         [176, 185, 194],
#         [174, 183, 192],
#         [174, 183, 190]],
#
#        [[131, 141, 150],
#         [134, 144, 153],
#         [121, 131, 140],
#         ...,
#         [184, 193, 202],
#         [174, 183, 192],
#         [176, 185, 192]],
#
#        [[129, 139, 148],
#         [135, 145, 154],
#         [125, 135, 144],
#         ...,
#         [180, 189, 198],
#         [181, 190, 199],
#         [177, 186, 193]],
#
#        ...,
#
#        [[ 20,  23,  30],
#         [  7,  10,  17],
#         [ 16,  19,  26],
#         ...,
#         [ 65,  65,  65],
#         [  2,   2,   2],
#         [  1,   1,   1]],
#
#        [[  4,   7,  14],
#         [ 11,  14,  21],
#         [  7,  10,  17],
#         ...,
#         [ 48,  48,  48],
#         [  3,   3,   3],
#         [  1,   1,   1]],
#
#        [[  5,   8,  15],
#         [ 11,  14,  21],
#         [  8,  11,  18],
#         ...,
#         [  6,   6,   6],
#         [  6,   6,   6],
#         [  1,   1,   1]]], dtype=uint8)

# %%
plt.imshow(fix_img_2)
plt.show()

# %%
img3 = cv2.flip(fix_img_2, 0)
plt.imshow(img3)
plt.show()

# %%
img3 = cv2.flip(fix_img_2, 1)
plt.imshow(img)
plt.show()

# %%
img3 = cv2.flip(fix_img_2, 3)
plt.imshow(img3)
plt.show()

# %%
cv2.imwrite('new genai image.jpg', img3)
# Out:
# True

# %%
pwd
# Out:
# 'C:\\Users\\telan\\Documents\\pythonroadmap'
