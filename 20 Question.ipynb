# %%
 #Q1. write a proggram to check if a number even or odd

# %%
x = int(input("Enter a number :"))
if x % 2 ==0:
    print("Even")
else:
    print("odd")
# Out:
# Enter a number : 5
# odd

# %%
 # Q2. check if a person is eligible to vote (age 18 or above)

# %%
x = int(input("Enter age of a person :"))
if x >= 18:
    print("eligible to vote")
else:
    print("not eligible to vote")
# Out:
# Enter age of a person : 16
# not eligible to vote

# %%
 #Q3. Determine if a given year is a leap year or not
x = int (input("Enter a number"))
if x % 4 == 0:
    print("It is a leap year")
else:
    print("It is a not a leap year")
# Out:
# Enter a number 2005
# It is a not a leap year

# %%
#Q4. Check if a number is positive,negative,or or zero
x = int(input("Enter a number"))
if x == 0:
    print("number is zero")
elif x>0:
    print("number is positive")
elif x<0:
    print("number is negative")
# Out:
# Enter a number 5
# number is positive

# %%
 #5. write a program to find the greatest of two numbers
a = int(input("Enter fisrt number:"))
b = int(input("Enter Second number:"))
if a > b:
    print("Gretest:",a)
else:
    print("gretest",b)
# Out:
# Enter fisrt number: 45
# Enter Second number: 55
# gretest 55

# %%
 # Q6. determine if a number is a multiple of 5

num = int(input("enter a number:"))
if num %5 == 0:
    print
    print("multiple of 5")
else:
    print("not a multiple  of 5")
# Out:
# enter a number: 40
# multiple of 5

# %%
 # check if a character is a vowel or constsnt
char = input("Enter a character:").lower()
if char in 'aeoiu':
    print("Vowel")
 else:
    print("Constant")
# Out:
# Enter a character: krishna
# Constant

# %%
 #Q8 Detremine ifa person is eligible for a senior citizen discount( age 60+)
age = int(input("Enter a age:"))
if age >= 60:
    print("Eligible for senior citizen discount")
else:
    print("no eliligible")
# Out:
# Enter a age: 55
# no eliligible

# %%
#Q9 check if a number is a single-digit number
num = int(input("Enter a number:"))
if 0 <= abs(num)< 10:
    print("single_digit number")
else:
    print("not a single-digit number")
# Out:
# Enter a number: 55
# not a single-digit number

# %%
 # Q 10> print" Good morining" if the time is before 12 pm. otherwise print"good afternoon")

hour = int(input("Enter hour(24-hour format):"))
if hour < 12:
    print("Good morning")
else:
    print("Good afternoon")
# Out:
# Enter hour(24-hour format): 12
# Good afternoon

# %%
 # Check if a string empty or not
s = input("Enter a string:")
if not s:
    print("string is empty")
else:
    print("string is not empty")
# Out:
# Enter a string:
# strin is not empty

# %%
 #Q12 > verify if a number is perfect square
import math
num = int(input("Enter a number."))
if math.isqrt(num) ** 2 == num:
    print("Perfec Square")
else:
    print("Not a perfect sqaure")
# Out:
# Enter a number. 25
# Perfec Square

# %%
 # 13> determine if a number is beteen 1 and 100
num = int(input("Enter a number:"))
if 1 <= num <=100:
    print("within range")
else:
    print("Out of range")
# Out:
# Enter a number: 75
# within range

# %%
 # Q14> print"weekend" if the dat Saturday or Sunday; otherwise,[rint"Weekday"
day = input("Enter a day:").lower()
if day in ["Saturday","sunday"]:
    print("Weekend")
else:
    print("Weekend")
# Out:
# Enter a day: sunday
# Weekend

# %%
 # Q15> find if a given number is exactly divisible by both 3 and 7
num = int(input("Enter a number:"))
if num % 3 == 0  and  num % 7 ==0:
    print("Divisible by 3 and 7")
else:
     print("Not divisible than both")
# Out:
# Enter a number: 21
# Divisible by 3 and 7

# %%
# 16 check if the sum of two numbers is greater than 100
a = int(input("enter a number:"))
if a> 100:
    print("greater than 100")
else: 
    print("less than 100")
# Out:
# enter a number: 451
# greater than 100

# %%
 # Q 17> Write a program to  find the minimum of two numbers
a = int(input("Enter first number :"))
b = int(input("enter second number:"))
if a<b:
    print("Minimum:",a)
else:
    print("Minimum:", b)
# Out:
# Enter first number : 56
# enter second number: 45
# Minimum: 45

# %%
 # Q18 Check if a number is divisible by 2 but not by 3
num = int(input("Enter a number:"))
if num % 2 == 0 and num % 3 !=0:
    print("Divisible by 2 but not by 3")
else:
    print("Does not meet criteria")
# Out:
# Enter a number: 18
# Does not meet criteria

# %%
 #Q19 Determine if a given alphabet is uppercase or lowercase
char = input("Enter an alphabet:")
if char.isupper():
    print("Uppercase")
else:
    print("Lowercase")
# Out:
# Enter an alphabet: KRISHNA
# Uppercase

# %%
 # Q 20> Check if a trianle is valid given three side lengths
a = int(input("Enter fisrt side:"))
b = int(input("Enter second side,"))
c = int(input("Enter third side:"))
if a + b > c and a + c > b and b + c > a:
    print("Valid Triangle")
else:
    print("Invalid Triangle")
# Out:
# Enter fisrt side: 4
# Enter second side, 5
# Enter third side: 6
# Valid Triangle
